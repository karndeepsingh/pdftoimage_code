# %%
# !pip install pdf2image
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/codemonk-admin/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install glob2
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/codemonk-admin/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import os

# %%
os.chdir("/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/unknown")

# %%
# from pdf2image import convert_from_path

# for sub_directories in os.listdir(path_to_directories):
#     os.mkdir("/media/karndeepsingh/Data-1/Data/pdf_to_images/{}".format(sub_directories))
#     print(sub_directories)
#     print("\n")
#     for ctg_directories in os.listdir(sub_directories):
#         #os.mkdir("/media/karndeepsingh/Data-1/Data/pdf_to_images/{}/{}".format(sub_directories,ctg_directories))
#         os.chdir( "/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/{}/{}".format(sub_directories,ctg_directories))
#         print(ctg_directories)
#         #for pdf_file in os.listdir("/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/{}/{}".format(sub_directories,ctg_directories)):
#         print("\n")
#             #print(pdf_file)
#             #if pdf_file.endswith(".pdf"):
#                 #pages = convert_from_path(pdf_file,450,output_folder="/media/karndeepsingh/Data-1/Data/pdf_to_images/{}/{}".format(sub_directories,ctg_directories),fmt="jpeg")
#                 #for page in pages:
                    
#                     #page.save("%s-page%d.jpg" % (pdf_file,pages.index(page)), "JPEG")
# os.chdir("/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput")

# %%
import time
def convert(file, outputDir):
    outputDir = outputDir + str(round(time.time()))
        #if not os.path.exists(outputDir):
             #os.makedirs(outputDir)
    try:
        pages = convert_from_path(file, 400)
    except Exception as e:
        print(e)
    finally:
        try:
            counter = 1
            for page in pages:
                myfile = outputDir +'output' + str(counter) +'.jpg'
                counter = counter + 1
                page.save(myfile, "JPEG")
                print(myfile)

        except Exception as e:
            print(e)

# %%
# os.listdir( "/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/tdp")

# %%
import PIL.Image
PIL.Image.MAX_IMAGE_PIXELS = None

# %%
# !pwd
# Out:
# /home/karndeepsingh/Documents/Unilever

# %%
from pdf2image import convert_from_path
path = "/media/karndeepsingh/Data-2/TDS PDF/"
outputDir = "/media/karndeepsingh/Data-2/TDS IMAGES/"
os.chdir(path)
# for ctg_dir in os.listdir(path):
# #     os.mkdir("/media/karndeepsingh/Data-1/Data/pdf_to_images/PDF_Structured/{}".format(ctg_dir))
#     outputDir = "/media/karndeepsingh/Data-1/Data/pdf_to_images/PDF_Structured/{}".format(ctg_dir)
#     #os.chdir( "/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/PDF_Print/{}".format(ctg_dir))
count=0   
for pdf_file in os.listdir(path):
    print(pdf_file)
    if pdf_file.endswith(".pdf"):
        convert(pdf_file, outputDir)
        count=count+1
    print(count)    
        
             
#             if pdf_file.endswith(".pdf"):
#                 convert(pdf_file,outputDir)
# Out:
# 2581_CARTON PWB 23G.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260488output1.jpg
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260488output2.jpg
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260488output3.jpg
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260488output4.jpg
# 1
# 1000_120226AP09 - SHELF SUPPORT.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260491output1.jpg
# 2
# 1000_foil Kupino.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260491output1.jpg
# 3
# 1000_HB 1452-0894.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260493output1.jpg
# 4
# 1000_Obj081352 - AP50041 _ A3.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260495output1.jpg
# 5
# 1001_500ml evergreen.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260496output1.jpg
# 6
# 1001_510000248780 3.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260497output1.jpg
# 7
# 1001_Knorr.pdf
# /media/karndeepsingh/Data-2/TDS IMAGES/1611260500output1.jpg
# 8
# 1001_obj030957.pdf
# ...

# %%
#Selecting Random Samples of images from the Folders
import shutil
import random
import glob

file_to_move = random.sample(glob.glob("/media/karndeepsingh/Data-1/Data/pdf_to_images/tds/*.jpg"),1200)
destination_folder = "/media/karndeepsingh/Data-1/Data/UDC/tds/"
for jpg_files in file_to_move:
    shutil.copy(jpg_files,destination_folder)

# %%
from pdf2jpg import pdf2jpg
results = pdf2jpg.convert_pdf2jpg("/media/karndeepsingh/Data-1/Data/Unilever Document Classification/DatasetExtractFramwiseOuput/tds/482_VL.pdf","./")

# %%
    print(myfile)
# Out:
# output_1.jpg

# %%
# !pwd
# Out:
# /home/karndeepsingh/Documents/Unilever

# %%
import os
 for file in os.listdir('.'):
        if file.endswith('.jpg'):
                os.remove(file)

# %%
for pdf_file in os.listdir("."):
    if pdf_file.endswith(".jpg"):
        print(pdf_file)
# Out:
# tds.jpg
